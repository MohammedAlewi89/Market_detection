# %%
import cv2
import pandas as pd
import numpy as np
from ultralytics import YOLO
from tracker import *

# Initialize YOLO model
model = YOLO('yolov8s.pt')

# Define areas of interest
area1 = [(312, 388), (289, 390), (474, 469), (497, 462)]
area2 = [(279, 392), (250, 397), (423, 477), (454, 469)]

# Initialize variables and objects
people_entering = {}
entering = set()
people_exiting = {}
exiting = set()
tracker = Tracker()

# save label of coco datasets
my_file = open("coco.txt", "r")
data = my_file.read()
class_list = data.split("\n") 

# Open video file
cap = cv2.VideoCapture('peoplecount1.mp4')

# Define codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output2.avi', fourcc, 20.0, (1020, 500))

while True:    
    ret, frame = cap.read()
    if not ret:
        break
    
    frame = cv2.resize(frame, (1020, 500))
    
    # Predict using YOLO model
    results = model.predict(frame)
    a = results[0].boxes.data
    px = pd.DataFrame(a).astype("float")
    
    list = []
             
    for index, row in px.iterrows():
        x1 = int(row[0])
        y1 = int(row[1])
        x2 = int(row[2])
        y2 = int(row[3])
        d = int(row[5])
        c = class_list[d]
        
        if 'person' in c:
           list.append([x1, y1, x2, y2])  
           
    bbox_id = tracker.update(list)
    
    for bbox in bbox_id:
        x3, y3, x4, y4, id = bbox
       
        # Determine if person is entering or exiting
        results = cv2.pointPolygonTest(np.array(area2, np.int32), ((x4, y4)), False)
        if results >= 0:
            people_entering[id] = (x4, y4)
            cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 0, 255), 2)
            
        if id in people_entering:
            results1 = cv2.pointPolygonTest(np.array(area1, np.int32), ((x4, y4)), False)
            if results1 >= 0:
                cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 255, 0), 2)
                cv2.circle(frame, (x4, y4), 4, (255, 0, 255), -1)
                cv2.putText(frame, str(c), (x3, y3-10), cv2.FONT_HERSHEY_COMPLEX, 0.5, (255, 255, 255), 1)
                cv2.putText(frame, str(id), (x3+65, y3-10), cv2.FONT_HERSHEY_COMPLEX, 0.5, (255, 0, 255), 1)
                entering.add(id)
        
        results2 = cv2.pointPolygonTest(np.array(area1, np.int32), ((x4, y4)), False)
        if results2 >= 0:
            people_exiting[id] = (x4, y4)
            cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 255, 0), 2)
        if id in people_exiting:
            results3 = cv2.pointPolygonTest(np.array(area2, np.int32), ((x4, y4)), False)
            if results3 >= 0:
                cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 0, 255), 2)
                cv2.circle(frame, (x4, y4), 4, (255, 0, 255), -1)
                cv2.putText(frame, str(c), (x3, y3-10), cv2.FONT_HERSHEY_COMPLEX, 0.5, (255, 255, 255), 1)
                cv2.putText(frame, str(id), (x3+55, y3-10), cv2.FONT_HERSHEY_COMPLEX, 0.5, (255, 0, 255), 1)
                exiting.add(id)
    
    # Draw areas of interest on the frame
    #cv2.polylines(frame, [np.array(area1, np.int32)], True, (255, 0, 0), 2)
    #cv2.putText(frame, str('1'), (504, 471), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0, 0), 2)

    #cv2.polylines(frame, [np.array(area2, np.int32)], True, (255, 0, 0), 2)
    #cv2.putText(frame, str('2'), (466, 485), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0, 0), 2)
    
    # Count entering and exiting people
    i = len(entering)
    o = len(exiting)
    cv2.putText(frame, 'No entering = ' + str(i), (20, 44), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 255, 0), 2)
    cv2.putText(frame, 'No exiting = ' + str(o), (20, 82), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0, 255), 2)
    
    # Write the frame to the output video
    out.write(frame)
    
    #cv2.imshow("RGB", frame)
    
    if cv2.waitKey(1) & 0xFF == 27:
        break

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 320x640 1 car, 164.6ms
# Speed: 3.0ms preprocess, 164.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 173.5ms
# Speed: 2.0ms preprocess, 173.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 164.6ms
# Speed: 2.0ms preprocess, 164.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 161.6ms
# Speed: 2.0ms preprocess, 161.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 168.5ms
# Speed: 2.0ms preprocess, 168.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 171.5ms
# Speed: 3.0ms preprocess, 171.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 155.6ms
# Speed: 2.0ms preprocess, 155.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 142.6ms
# Speed: 2.0ms preprocess, 142.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 166.6ms
# Speed: 2.0ms preprocess, 166.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 161.6ms
# Speed: 2.0ms preprocess, 161.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 156.6ms
# Speed: 2.0ms preprocess, 156.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 165.6ms
# Speed: 2.0ms preprocess, 165.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 156.6ms
# Speed: 2.0ms preprocess, 156.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 169.5ms
# Speed: 3.0ms preprocess, 169.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 152.6ms
# Speed: 2.0ms preprocess, 152.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 160.6ms
# Speed: 3.0ms preprocess, 160.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 162.6ms
# Speed: 2.0ms preprocess, 162.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 171.5ms
# Speed: 2.0ms preprocess, 171.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 176.5ms
# Speed: 3.0ms preprocess, 176.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 156.6ms
# Speed: 2.0ms preprocess, 156.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 169.5ms
# Speed: 3.0ms preprocess, 169.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 182.5ms
# Speed: 2.0ms preprocess, 182.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 174.5ms
# Speed: 2.0ms preprocess, 174.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 153.6ms
# Speed: 3.0ms preprocess, 153.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 161.6ms
# Speed: 3.0ms preprocess, 161.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 192.5ms
# Speed: 3.0ms preprocess, 192.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 177.5ms
# Speed: 2.0ms preprocess, 177.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 187.5ms
# Speed: 3.0ms preprocess, 187.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 1 potted plant, 165.6ms
# Speed: 3.0ms preprocess, 165.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 1 potted plant, 233.4ms
# Speed: 2.0ms preprocess, 233.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 182.5ms
# Speed: 3.0ms preprocess, 182.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 168.6ms
# Speed: 3.0ms preprocess, 168.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 164.6ms
# Speed: 3.0ms preprocess, 164.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 189.5ms
# Speed: 3.0ms preprocess, 189.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 1 skateboard, 191.5ms
# Speed: 4.0ms preprocess, 191.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 199.5ms
# Speed: 3.0ms preprocess, 199.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 186.5ms
# Speed: 2.0ms preprocess, 186.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 184.5ms
# Speed: 4.0ms preprocess, 184.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 203.5ms
# Speed: 3.0ms preprocess, 203.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 2 cars, 176.5ms
# Speed: 3.0ms preprocess, 176.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 3 cars, 167.6ms
# Speed: 2.0ms preprocess, 167.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 2 cars, 175.5ms
# Speed: 2.0ms preprocess, 175.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 cars, 195.5ms
# Speed: 2.0ms preprocess, 195.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 cars, 164.6ms
# Speed: 3.0ms preprocess, 164.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 190.5ms
# Speed: 3.0ms preprocess, 190.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 1 car, 165.6ms
# Speed: 2.0ms preprocess, 165.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 1 car, 184.5ms
# Speed: 3.0ms preprocess, 184.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 175.5ms
# Speed: 2.0ms preprocess, 175.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 164.6ms
# Speed: 3.0ms preprocess, 164.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 171.5ms
# Speed: 2.0ms preprocess, 171.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 176.5ms
# Speed: 2.0ms preprocess, 176.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 173.5ms
# Speed: 2.0ms preprocess, 173.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 180.5ms
# Speed: 2.0ms preprocess, 180.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 175.5ms
# Speed: 3.0ms preprocess, 175.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 181.5ms
# Speed: 3.0ms preprocess, 181.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 186.5ms
# Speed: 4.0ms preprocess, 186.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 183.5ms
# Speed: 2.0ms preprocess, 183.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 184.5ms
# Speed: 2.0ms preprocess, 184.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 186.5ms
# Speed: 3.0ms preprocess, 186.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 182.5ms
# Speed: 2.0ms preprocess, 182.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 165.6ms
# Speed: 3.0ms preprocess, 165.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 191.5ms
# Speed: 3.0ms preprocess, 191.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 183.5ms
# Speed: 3.0ms preprocess, 183.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 165.6ms
# Speed: 2.0ms preprocess, 165.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 185.5ms
# Speed: 2.0ms preprocess, 185.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 1 car, 173.5ms
# Speed: 2.0ms preprocess, 173.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 168.6ms
# Speed: 3.0ms preprocess, 168.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 178.5ms
# Speed: 2.0ms preprocess, 178.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 166.6ms
# Speed: 2.0ms preprocess, 166.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 161.6ms
# Speed: 2.0ms preprocess, 161.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 175.5ms
# Speed: 3.0ms preprocess, 175.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 167.6ms
# Speed: 2.0ms preprocess, 167.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 185.5ms
# Speed: 2.0ms preprocess, 185.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 180.5ms
# Speed: 3.0ms preprocess, 180.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 193.5ms
# Speed: 2.0ms preprocess, 193.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 184.5ms
# Speed: 2.0ms preprocess, 184.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 184.5ms
# Speed: 2.0ms preprocess, 184.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 184.5ms
# Speed: 3.0ms preprocess, 184.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 201.5ms
# Speed: 4.0ms preprocess, 201.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 handbag, 183.5ms
# Speed: 3.0ms preprocess, 183.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 169.5ms
# Speed: 3.0ms preprocess, 169.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 184.5ms
# Speed: 3.0ms preprocess, 184.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 200.5ms
# Speed: 2.0ms preprocess, 200.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 193.5ms
# Speed: 3.0ms preprocess, 193.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 189.5ms
# Speed: 2.0ms preprocess, 189.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 183.5ms
# Speed: 2.0ms preprocess, 183.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 187.5ms
# Speed: 3.0ms preprocess, 187.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 184.5ms
# Speed: 2.0ms preprocess, 184.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 180.5ms
# Speed: 3.0ms preprocess, 180.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 186.5ms
# Speed: 3.0ms preprocess, 186.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 187.5ms
# Speed: 2.0ms preprocess, 187.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 191.5ms
# Speed: 3.0ms preprocess, 191.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 174.5ms
# Speed: 2.0ms preprocess, 174.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 188.5ms
# Speed: 3.0ms preprocess, 188.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 190.5ms
# Speed: 3.0ms preprocess, 190.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 186.5ms
# Speed: 2.0ms preprocess, 186.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 173.5ms
# Speed: 3.0ms preprocess, 173.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 175.5ms
# Speed: 3.0ms preprocess, 175.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 190.5ms
# Speed: 2.0ms preprocess, 190.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 180.5ms
# Speed: 3.0ms preprocess, 180.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 189.5ms
# Speed: 3.0ms preprocess, 189.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 179.6ms
# Speed: 3.0ms preprocess, 179.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 182.5ms
# Speed: 2.0ms preprocess, 182.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 211.4ms
# Speed: 3.0ms preprocess, 211.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 187.5ms
# Speed: 3.0ms preprocess, 187.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 backpack, 195.5ms
# Speed: 3.0ms preprocess, 195.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 198.5ms
# Speed: 3.0ms preprocess, 198.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 195.5ms
# Speed: 2.0ms preprocess, 195.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 171.5ms
# Speed: 2.0ms preprocess, 171.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 169.5ms
# Speed: 2.0ms preprocess, 169.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 163.6ms
# Speed: 3.0ms preprocess, 163.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 181.5ms
# Speed: 2.0ms preprocess, 181.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 181.5ms
# Speed: 3.0ms preprocess, 181.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 190.5ms
# Speed: 2.0ms preprocess, 190.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 178.5ms
# Speed: 2.0ms preprocess, 178.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 182.5ms
# Speed: 2.0ms preprocess, 182.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 191.5ms
# Speed: 2.0ms preprocess, 191.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 170.5ms
# Speed: 2.0ms preprocess, 170.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 202.5ms
# Speed: 2.0ms preprocess, 202.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 171.5ms
# Speed: 3.0ms preprocess, 171.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 202.5ms
# Speed: 3.0ms preprocess, 202.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 182.5ms
# Speed: 2.0ms preprocess, 182.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 175.5ms
# Speed: 3.0ms preprocess, 175.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 164.6ms
# Speed: 3.0ms preprocess, 164.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 195.5ms
# Speed: 2.0ms preprocess, 195.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 320x640 1 person, 196.5ms
# Speed: 3.0ms preprocess, 196.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 176.5ms
# Speed: 2.0ms preprocess, 176.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 171.5ms
# Speed: 3.0ms preprocess, 171.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 176.5ms
# Speed: 3.0ms preprocess, 176.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 184.5ms
# Speed: 2.0ms preprocess, 184.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 178.5ms
# Speed: 3.0ms preprocess, 178.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 171.5ms
# Speed: 3.0ms preprocess, 171.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 192.5ms
# Speed: 3.0ms preprocess, 192.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 183.5ms
# Speed: 2.0ms preprocess, 183.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 190.5ms
# Speed: 3.0ms preprocess, 190.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 187.5ms
# Speed: 2.0ms preprocess, 187.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 175.5ms
# Speed: 2.0ms preprocess, 175.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 185.5ms
# Speed: 3.0ms preprocess, 185.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 179.5ms
# Speed: 3.0ms preprocess, 179.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 195.5ms
# Speed: 2.0ms preprocess, 195.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 175.5ms
# Speed: 1.0ms preprocess, 175.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 185.5ms
# Speed: 3.0ms preprocess, 185.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 198.5ms
# Speed: 2.0ms preprocess, 198.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 166.6ms
# Speed: 2.0ms preprocess, 166.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 175.5ms
# Speed: 3.0ms preprocess, 175.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 190.5ms
# Speed: 2.0ms preprocess, 190.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 189.5ms
# Speed: 2.0ms preprocess, 189.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 179.5ms
# Speed: 3.0ms preprocess, 179.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 189.5ms
# Speed: 2.0ms preprocess, 189.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 185.5ms
# Speed: 2.0ms preprocess, 185.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 184.5ms
# Speed: 2.0ms preprocess, 184.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 175.5ms
# Speed: 2.0ms preprocess, 175.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 185.5ms
# Speed: 2.0ms preprocess, 185.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 165.6ms
# Speed: 3.0ms preprocess, 165.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 181.5ms
# Speed: 3.0ms preprocess, 181.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 196.5ms
# Speed: 2.0ms preprocess, 196.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 167.5ms
# Speed: 2.0ms preprocess, 167.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 187.5ms
# Speed: 2.0ms preprocess, 187.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 170.5ms
# Speed: 3.0ms preprocess, 170.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 170.5ms
# Speed: 2.0ms preprocess, 170.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 192.5ms
# Speed: 2.0ms preprocess, 192.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 190.5ms
# Speed: 3.0ms preprocess, 190.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 187.5ms
# Speed: 2.0ms preprocess, 187.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 193.5ms
# Speed: 3.0ms preprocess, 193.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 190.5ms
# Speed: 3.0ms preprocess, 190.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 189.5ms
# Speed: 2.0ms preprocess, 189.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 180.5ms
# Speed: 3.0ms preprocess, 180.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 176.5ms
# Speed: 4.0ms preprocess, 176.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 175.5ms
# Speed: 3.0ms preprocess, 175.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 200.5ms
# Speed: 4.0ms preprocess, 200.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 192.5ms
# Speed: 3.0ms preprocess, 192.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 205.5ms
# Speed: 2.0ms preprocess, 205.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 197.5ms
# Speed: 3.0ms preprocess, 197.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 197.5ms
# Speed: 3.0ms preprocess, 197.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 194.5ms
# Speed: 3.0ms preprocess, 194.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 192.5ms
# Speed: 4.0ms preprocess, 192.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 177.5ms
# Speed: 3.0ms preprocess, 177.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 168.5ms
# Speed: 3.0ms preprocess, 168.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 171.5ms
# Speed: 3.0ms preprocess, 171.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 171.5ms
# Speed: 4.0ms preprocess, 171.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 200.5ms
# Speed: 2.0ms preprocess, 200.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 188.5ms
# Speed: 2.0ms preprocess, 188.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 190.5ms
# Speed: 3.0ms preprocess, 190.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 177.5ms
# Speed: 3.0ms preprocess, 177.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 192.5ms
# Speed: 2.0ms preprocess, 192.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 197.5ms
# Speed: 3.0ms preprocess, 197.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 204.5ms
# Speed: 3.0ms preprocess, 204.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 182.5ms
# Speed: 2.0ms preprocess, 182.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 189.5ms
# Speed: 2.0ms preprocess, 189.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 320x640 1 person, 178.5ms
# Speed: 4.0ms preprocess, 178.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 201.5ms
# Speed: 2.0ms preprocess, 201.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 191.5ms
# Speed: 2.0ms preprocess, 191.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 177.5ms
# Speed: 3.0ms preprocess, 177.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 193.5ms
# Speed: 3.0ms preprocess, 193.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 167.6ms
# Speed: 2.0ms preprocess, 167.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 185.5ms
# Speed: 2.0ms preprocess, 185.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 175.5ms
# Speed: 3.0ms preprocess, 175.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 187.5ms
# Speed: 3.0ms preprocess, 187.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 185.5ms
# Speed: 2.0ms preprocess, 185.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 193.5ms
# Speed: 3.0ms preprocess, 193.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 185.5ms
# Speed: 3.0ms preprocess, 185.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 170.5ms
# Speed: 2.0ms preprocess, 170.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 174.5ms
# Speed: 2.0ms preprocess, 174.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 184.5ms
# Speed: 2.0ms preprocess, 184.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 181.5ms
# Speed: 3.0ms preprocess, 181.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 191.5ms
# Speed: 3.0ms preprocess, 191.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 191.5ms
# Speed: 2.0ms preprocess, 191.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 178.5ms
# Speed: 2.0ms preprocess, 178.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 189.5ms
# Speed: 3.0ms preprocess, 189.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 170.5ms
# Speed: 2.0ms preprocess, 170.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 178.5ms
# Speed: 2.0ms preprocess, 178.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 197.5ms
# Speed: 2.0ms preprocess, 197.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 176.5ms
# Speed: 3.0ms preprocess, 176.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 177.5ms
# Speed: 3.0ms preprocess, 177.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 183.5ms
# Speed: 3.0ms preprocess, 183.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 169.5ms
# Speed: 3.0ms preprocess, 169.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 185.5ms
# Speed: 2.0ms preprocess, 185.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 198.5ms
# Speed: 3.0ms preprocess, 198.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 171.5ms
# Speed: 2.0ms preprocess, 171.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 176.5ms
# Speed: 3.0ms preprocess, 176.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 204.5ms
# Speed: 2.0ms preprocess, 204.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 191.5ms
# Speed: 4.0ms preprocess, 191.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 189.5ms
# Speed: 3.0ms preprocess, 189.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 182.5ms
# Speed: 3.0ms preprocess, 182.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 183.5ms
# Speed: 3.0ms preprocess, 183.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 170.5ms
# Speed: 3.0ms preprocess, 170.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 164.6ms
# Speed: 3.0ms preprocess, 164.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 189.5ms
# Speed: 2.0ms preprocess, 189.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 198.5ms
# Speed: 3.0ms preprocess, 198.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 191.5ms
# Speed: 3.0ms preprocess, 191.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 190.5ms
# Speed: 3.0ms preprocess, 190.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 182.5ms
# Speed: 3.0ms preprocess, 182.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 169.5ms
# Speed: 3.0ms preprocess, 169.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 192.5ms
# Speed: 3.0ms preprocess, 192.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 189.5ms
# Speed: 3.0ms preprocess, 189.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 159.6ms
# Speed: 2.0ms preprocess, 159.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 174.5ms
# Speed: 3.0ms preprocess, 174.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 177.5ms
# Speed: 3.0ms preprocess, 177.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 183.5ms
# Speed: 3.0ms preprocess, 183.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 168.5ms
# Speed: 3.0ms preprocess, 168.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 181.5ms
# Speed: 3.0ms preprocess, 181.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 165.6ms
# Speed: 3.0ms preprocess, 165.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 cars, 163.6ms
# Speed: 2.0ms preprocess, 163.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 173.5ms
# Speed: 2.0ms preprocess, 173.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 181.5ms
# Speed: 3.0ms preprocess, 181.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 184.5ms
# Speed: 3.0ms preprocess, 184.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 172.5ms
# Speed: 3.0ms preprocess, 172.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 162.6ms
# Speed: 3.0ms preprocess, 162.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 160.6ms
# Speed: 3.0ms preprocess, 160.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 190.5ms
# Speed: 3.0ms preprocess, 190.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 188.5ms
# Speed: 3.0ms preprocess, 188.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 175.5ms
# Speed: 3.0ms preprocess, 175.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 170.5ms
# Speed: 2.0ms preprocess, 170.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 320x640 1 person, 184.5ms
# Speed: 2.0ms preprocess, 184.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 166.6ms
# Speed: 3.0ms preprocess, 166.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 195.5ms
# Speed: 3.0ms preprocess, 195.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 190.5ms
# Speed: 2.0ms preprocess, 190.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 188.5ms
# Speed: 3.0ms preprocess, 188.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 192.5ms
# Speed: 2.0ms preprocess, 192.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 187.5ms
# Speed: 2.0ms preprocess, 187.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 173.5ms
# Speed: 3.0ms preprocess, 173.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 179.5ms
# Speed: 3.0ms preprocess, 179.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 190.5ms
# Speed: 3.0ms preprocess, 190.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 179.5ms
# Speed: 3.0ms preprocess, 179.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 169.5ms
# Speed: 3.0ms preprocess, 169.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 163.6ms
# Speed: 3.0ms preprocess, 163.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 179.5ms
# Speed: 4.0ms preprocess, 179.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 193.5ms
# Speed: 2.0ms preprocess, 193.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 174.5ms
# Speed: 3.0ms preprocess, 174.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 186.5ms
# Speed: 3.0ms preprocess, 186.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 174.5ms
# Speed: 2.0ms preprocess, 174.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 166.6ms
# Speed: 3.0ms preprocess, 166.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 194.5ms
# Speed: 2.0ms preprocess, 194.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 186.5ms
# Speed: 3.0ms preprocess, 186.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 187.5ms
# Speed: 2.0ms preprocess, 187.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 180.5ms
# Speed: 3.0ms preprocess, 180.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 190.5ms
# Speed: 2.0ms preprocess, 190.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 177.5ms
# Speed: 3.0ms preprocess, 177.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 203.5ms
# Speed: 2.0ms preprocess, 203.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 175.5ms
# Speed: 3.0ms preprocess, 175.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 191.5ms
# Speed: 3.0ms preprocess, 191.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 173.5ms
# Speed: 2.0ms preprocess, 173.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 162.6ms
# Speed: 3.0ms preprocess, 162.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 196.5ms
# Speed: 2.0ms preprocess, 196.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 184.5ms
# Speed: 3.0ms preprocess, 184.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 backpack, 182.5ms
# Speed: 3.0ms preprocess, 182.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 backpack, 163.6ms
# Speed: 3.0ms preprocess, 163.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 170.5ms
# Speed: 3.0ms preprocess, 170.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 189.5ms
# Speed: 3.0ms preprocess, 189.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 backpack, 195.5ms
# Speed: 2.0ms preprocess, 195.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 backpack, 183.5ms
# Speed: 2.0ms preprocess, 183.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 backpack, 190.5ms
# Speed: 4.0ms preprocess, 190.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 backpack, 177.5ms
# Speed: 2.0ms preprocess, 177.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 backpack, 181.5ms
# Speed: 4.0ms preprocess, 181.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 backpack, 186.5ms
# Speed: 4.0ms preprocess, 186.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 backpack, 177.5ms
# Speed: 2.0ms preprocess, 177.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 backpack, 188.5ms
# Speed: 3.0ms preprocess, 188.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 backpack, 184.5ms
# Speed: 3.0ms preprocess, 184.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 backpack, 180.5ms
# Speed: 3.0ms preprocess, 180.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 backpack, 171.5ms
# Speed: 3.0ms preprocess, 171.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 backpack, 169.5ms
# Speed: 4.0ms preprocess, 169.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 backpack, 199.5ms
# Speed: 2.0ms preprocess, 199.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 backpack, 160.6ms
# Speed: 3.0ms preprocess, 160.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 1 backpack, 189.5ms
# Speed: 2.0ms preprocess, 189.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 1 skateboard, 175.5ms
# Speed: 3.0ms preprocess, 175.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 1 car, 186.5ms
# Speed: 3.0ms preprocess, 186.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 1 car, 181.5ms
# Speed: 3.0ms preprocess, 181.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 1 handbag, 181.5ms
# Speed: 3.0ms preprocess, 181.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 1 handbag, 193.5ms
# Speed: 2.0ms preprocess, 193.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 2 handbags, 206.4ms
# Speed: 3.0ms preprocess, 206.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 cars, 1 handbag, 204.5ms
# Speed: 2.0ms preprocess, 204.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 cars, 1 handbag, 169.5ms
# Speed: 2.0ms preprocess, 169.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 cars, 2 handbags, 195.5ms
# Speed: 2.0ms preprocess, 195.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 cars, 1 handbag, 191.5ms
# Speed: 3.0ms preprocess, 191.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 320x640 2 persons, 2 cars, 2 handbags, 197.5ms
# Speed: 3.0ms preprocess, 197.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 cars, 2 handbags, 166.6ms
# Speed: 2.0ms preprocess, 166.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 cars, 3 handbags, 181.5ms
# Speed: 2.0ms preprocess, 181.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 2 handbags, 152.6ms
# Speed: 2.0ms preprocess, 152.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 1 handbag, 183.5ms
# Speed: 3.0ms preprocess, 183.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 3 handbags, 194.5ms
# Speed: 3.0ms preprocess, 194.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 2 handbags, 182.5ms
# Speed: 3.0ms preprocess, 182.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 1 handbag, 186.5ms
# Speed: 3.0ms preprocess, 186.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 2 handbags, 183.5ms
# Speed: 3.0ms preprocess, 183.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 3 cars, 1 handbag, 195.5ms
# Speed: 3.0ms preprocess, 195.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 cars, 2 handbags, 181.5ms
# Speed: 2.0ms preprocess, 181.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 1 handbag, 176.5ms
# Speed: 3.0ms preprocess, 176.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 2 handbags, 182.5ms
# Speed: 3.0ms preprocess, 182.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 1 handbag, 182.5ms
# Speed: 3.0ms preprocess, 182.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 cars, 2 handbags, 192.5ms
# Speed: 3.0ms preprocess, 192.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 2 handbags, 193.5ms
# Speed: 3.0ms preprocess, 193.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 cars, 184.5ms
# Speed: 2.0ms preprocess, 184.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 3 cars, 186.5ms
# Speed: 3.0ms preprocess, 186.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 3 cars, 1 handbag, 160.6ms
# Speed: 2.0ms preprocess, 160.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 cars, 2 handbags, 185.5ms
# Speed: 3.0ms preprocess, 185.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 cars, 3 handbags, 200.5ms
# Speed: 3.0ms preprocess, 200.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 cars, 2 handbags, 188.5ms
# Speed: 2.0ms preprocess, 188.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 3 handbags, 183.5ms
# Speed: 3.0ms preprocess, 183.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 2 handbags, 177.5ms
# Speed: 3.0ms preprocess, 177.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 handbags, 1 potted plant, 166.6ms
# Speed: 2.0ms preprocess, 166.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 handbags, 193.5ms
# Speed: 4.0ms preprocess, 193.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 handbag, 188.5ms
# Speed: 3.0ms preprocess, 188.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 handbag, 185.5ms
# Speed: 3.0ms preprocess, 185.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 164.6ms
# Speed: 3.0ms preprocess, 164.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 192.5ms
# Speed: 3.0ms preprocess, 192.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 190.5ms
# Speed: 3.0ms preprocess, 190.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 185.5ms
# Speed: 3.0ms preprocess, 185.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 189.5ms
# Speed: 2.0ms preprocess, 189.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 181.5ms
# Speed: 2.0ms preprocess, 181.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 174.5ms
# Speed: 3.0ms preprocess, 174.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 handbag, 185.5ms
# Speed: 3.0ms preprocess, 185.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 handbag, 189.5ms
# Speed: 3.0ms preprocess, 189.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 handbag, 190.5ms
# Speed: 3.0ms preprocess, 190.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 handbag, 1 tv, 194.5ms
# Speed: 3.0ms preprocess, 194.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 handbag, 182.5ms
# Speed: 3.0ms preprocess, 182.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 handbag, 179.5ms
# Speed: 3.0ms preprocess, 179.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 handbags, 215.4ms
# Speed: 2.0ms preprocess, 215.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 handbag, 217.4ms
# Speed: 3.0ms preprocess, 217.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 handbag, 204.5ms
# Speed: 4.0ms preprocess, 204.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 handbag, 227.4ms
# Speed: 3.0ms preprocess, 227.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 handbags, 220.4ms
# Speed: 3.0ms preprocess, 220.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 2 handbags, 225.4ms
# Speed: 3.0ms preprocess, 225.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 2 handbags, 1 tv, 241.4ms
# Speed: 3.0ms preprocess, 241.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# ...
#
# 0: 320x640 (no detections), 193.5ms
# Speed: 2.0ms preprocess, 193.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 177.6ms
# Speed: 3.0ms preprocess, 177.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 179.5ms
# Speed: 3.0ms preprocess, 179.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 192.5ms
# Speed: 2.0ms preprocess, 192.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 186.5ms
# Speed: 2.0ms preprocess, 186.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 178.5ms
# Speed: 2.0ms preprocess, 178.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 176.5ms
# Speed: 3.0ms preprocess, 176.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 190.5ms
# Speed: 3.0ms preprocess, 190.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 194.5ms
# Speed: 2.0ms preprocess, 194.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 235.3ms
# Speed: 3.0ms preprocess, 235.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 220.4ms
# Speed: 4.0ms preprocess, 220.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 216.4ms
# Speed: 3.0ms preprocess, 216.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 223.4ms
# Speed: 4.0ms preprocess, 223.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 201.5ms
# Speed: 4.0ms preprocess, 201.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 217.4ms
# Speed: 3.0ms preprocess, 217.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 217.4ms
# Speed: 2.0ms preprocess, 217.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 204.5ms
# Speed: 3.0ms preprocess, 204.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 183.5ms
# Speed: 3.0ms preprocess, 183.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 198.5ms
# Speed: 3.0ms preprocess, 198.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 177.5ms
# Speed: 3.0ms preprocess, 177.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 199.5ms
# Speed: 3.0ms preprocess, 199.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 216.4ms
# Speed: 3.0ms preprocess, 216.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 213.4ms
# Speed: 3.0ms preprocess, 213.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 215.4ms
# Speed: 2.0ms preprocess, 215.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 220.4ms
# Speed: 3.0ms preprocess, 220.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 200.5ms
# Speed: 2.0ms preprocess, 200.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 223.4ms
# Speed: 4.0ms preprocess, 223.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 214.4ms
# Speed: 4.0ms preprocess, 214.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 191.5ms
# Speed: 2.0ms preprocess, 191.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 200.5ms
# Speed: 3.0ms preprocess, 200.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 185.5ms
# Speed: 3.0ms preprocess, 185.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 192.5ms
# Speed: 2.0ms preprocess, 192.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 192.5ms
# Speed: 2.0ms preprocess, 192.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 179.5ms
# Speed: 3.0ms preprocess, 179.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 175.5ms
# Speed: 3.0ms preprocess, 175.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 202.5ms
# Speed: 3.0ms preprocess, 202.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 194.5ms
# Speed: 1.0ms preprocess, 194.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 176.5ms
# Speed: 2.0ms preprocess, 176.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 193.5ms
# Speed: 4.0ms preprocess, 193.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 188.5ms
# Speed: 3.0ms preprocess, 188.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 193.5ms
# Speed: 4.0ms preprocess, 193.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 182.5ms
# Speed: 2.0ms preprocess, 182.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 171.5ms
# Speed: 3.0ms preprocess, 171.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 182.5ms
# Speed: 2.0ms preprocess, 182.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 183.5ms
# Speed: 3.0ms preprocess, 183.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 178.5ms
# Speed: 2.0ms preprocess, 178.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 174.5ms
# Speed: 3.0ms preprocess, 174.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 203.5ms
# Speed: 2.0ms preprocess, 203.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 184.5ms
# Speed: 3.0ms preprocess, 184.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 191.5ms
# Speed: 3.0ms preprocess, 191.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 174.5ms
# Speed: 2.0ms preprocess, 174.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 tv, 191.5ms
# Speed: 2.0ms preprocess, 191.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 tv, 204.5ms
# Speed: 2.0ms preprocess, 204.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 tv, 159.6ms
# Speed: 2.0ms preprocess, 159.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 tv, 190.5ms
# Speed: 4.0ms preprocess, 190.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 182.5ms
# Speed: 2.0ms preprocess, 182.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 193.5ms
# Speed: 3.0ms preprocess, 193.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 241.4ms
# Speed: 2.0ms preprocess, 241.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 232.4ms
# Speed: 3.0ms preprocess, 232.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 240.4ms
# Speed: 4.0ms preprocess, 240.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 277.3ms
# Speed: 4.0ms preprocess, 277.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 274.3ms
# Speed: 4.0ms preprocess, 274.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 233.4ms
# Speed: 3.0ms preprocess, 233.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 274.3ms
# Speed: 3.0ms preprocess, 274.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 274.3ms
# Speed: 3.0ms preprocess, 274.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 215.4ms
# Speed: 6.0ms preprocess, 215.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 220.4ms
# Speed: 2.0ms preprocess, 220.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 201.5ms
# Speed: 3.0ms preprocess, 201.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 206.4ms
# Speed: 3.0ms preprocess, 206.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 214.4ms
# Speed: 4.0ms preprocess, 214.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 226.4ms
# Speed: 4.0ms preprocess, 226.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 227.4ms
# Speed: 4.0ms preprocess, 227.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 205.4ms
# Speed: 2.0ms preprocess, 205.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 209.4ms
# Speed: 4.0ms preprocess, 209.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 199.5ms
# Speed: 4.0ms preprocess, 199.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 191.5ms
# Speed: 3.0ms preprocess, 191.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 204.5ms
# Speed: 3.0ms preprocess, 204.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 190.5ms
# Speed: 3.0ms preprocess, 190.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 216.4ms
# Speed: 3.0ms preprocess, 216.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 181.5ms
# Speed: 2.0ms preprocess, 181.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 194.5ms
# Speed: 3.0ms preprocess, 194.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 204.4ms
# Speed: 3.0ms preprocess, 204.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 230.4ms
# Speed: 3.0ms preprocess, 230.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 189.5ms
# Speed: 3.0ms preprocess, 189.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 257.3ms
# Speed: 3.0ms preprocess, 257.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 227.4ms
# Speed: 3.0ms preprocess, 227.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 206.4ms
# Speed: 3.0ms preprocess, 206.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 200.5ms
# Speed: 2.0ms preprocess, 200.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 194.5ms
# Speed: 2.0ms preprocess, 194.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 204.5ms
# Speed: 2.0ms preprocess, 204.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 0: 320x640 2 persons, 208.4ms
# Speed: 3.0ms preprocess, 208.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 218.4ms
# Speed: 3.0ms preprocess, 218.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 209.4ms
# Speed: 3.0ms preprocess, 209.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 194.5ms
# Speed: 3.0ms preprocess, 194.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 211.4ms
# Speed: 3.0ms preprocess, 211.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 198.5ms
# Speed: 2.0ms preprocess, 198.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 197.5ms
# Speed: 3.0ms preprocess, 197.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 200.5ms
# Speed: 3.0ms preprocess, 200.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 200.5ms
# Speed: 2.0ms preprocess, 200.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 169.5ms
# Speed: 3.0ms preprocess, 169.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 281.2ms
# Speed: 2.0ms preprocess, 281.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 239.4ms
# Speed: 3.0ms preprocess, 239.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 277.3ms
# Speed: 4.0ms preprocess, 277.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 228.4ms
# Speed: 3.0ms preprocess, 228.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 199.5ms
# Speed: 2.0ms preprocess, 199.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 212.4ms
# Speed: 2.0ms preprocess, 212.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 183.5ms
# Speed: 4.0ms preprocess, 183.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 180.5ms
# Speed: 3.0ms preprocess, 180.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 186.5ms
# Speed: 3.0ms preprocess, 186.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 skateboard, 203.5ms
# Speed: 2.0ms preprocess, 203.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 193.5ms
# Speed: 3.0ms preprocess, 193.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 207.4ms
# Speed: 2.0ms preprocess, 207.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 191.5ms
# Speed: 3.0ms preprocess, 191.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 180.5ms
# Speed: 3.0ms preprocess, 180.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 167.5ms
# Speed: 3.0ms preprocess, 167.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 1 skateboard, 186.5ms
# Speed: 3.0ms preprocess, 186.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 skateboard, 198.5ms
# Speed: 2.0ms preprocess, 198.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 209.4ms
# Speed: 2.0ms preprocess, 209.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 195.5ms
# Speed: 4.0ms preprocess, 195.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 190.5ms
# Speed: 2.0ms preprocess, 190.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 215.4ms
# Speed: 3.0ms preprocess, 215.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 227.4ms
# Speed: 3.0ms preprocess, 227.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
